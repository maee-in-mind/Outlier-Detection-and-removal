# %%
#removing outliers from dataframe using IQR method
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("outlier.csv")
df.head()
# Out:
#     v1   v2
# 0    1    2
# 1    2    4
# 2    3    1
# 3  120  236
# 4  120  354

# %%
df.tail()
# Out:
#        v1     v2
# 46    140    235
# 47  10000  10000
# 48  20000   1000
# 49  10000  10000
# 50  20000  20000

# %%
plt.boxplot(df)
df.plot(kind='bar')

# %%
df.shape
# Out:
# (51, 2)

# %%
#df have significant outliers in it let us remove it using Inter-Quartile_Range(IQR)
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1

# %%
#let us find out the Lower and higher outliers
lower_outlier=Q1-(1.5*IQR)
higher_outlier=Q3+(1.5*IQR)

# %%
#dataframe without lower outlier is as follows
df_without_lower_outlier = df[~((df < lower_outlier))]

# %%
df_without_lower_outlier
# Out:
#          v1       v2
# 0       NaN      NaN
# 1       NaN      NaN
# 2       NaN      NaN
# 3     120.0    236.0
# 4     120.0    354.0
# 5     140.0    192.0
# 6     140.0    294.0
# 7     120.0    263.0
# 8     172.0    199.0
# 9     150.0    168.0
# 10    140.0    239.0
# 11    130.0    275.0
# 12    130.0    266.0
# 13    110.0    211.0
# 14    150.0    283.0
# 15    120.0    219.0
# 16    120.0    340.0
# 17    150.0    226.0
# 18    150.0    247.0
# 19    140.0    239.0
# 20    135.0    234.0
# 21    130.0    233.0
# 22    140.0    226.0
# 23    150.0    243.0
# 24    140.0    199.0
# 25    160.0    302.0
# 26    150.0    212.0
# 27    110.0    175.0
# 28    140.0    417.0
# 29    130.0    197.0
# 30    105.0    198.0
# 31    120.0    177.0
# 32    130.0    219.0
# 33    125.0    273.0
# 34    125.0    213.0
# 35    142.0    177.0
# 36    135.0    304.0
# 37    150.0    232.0
# 38    155.0    269.0
# 39    160.0    360.0
# 40    140.0    308.0
# 41    130.0    245.0
# ...

# %%
plt.boxplot(df_without_lower_outlier)
df_without_lower_outlier.plot(kind='bar')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3652: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1246: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1253: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1261: RuntimeWarning: invalid value encountered in less
#   np.compress(x < stats['whislo'], x),
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1262: RuntimeWarning: invalid value encountered in greater
#   np.compress(x > stats['whishi'], x)

# %%
#dataframe without higher outlier is as follows
df_without_higher_outlier = df[~((df > higher_outlier))]

# %%
df_without_higher_outlier
# Out:
#        v1     v2
# 0     1.0    2.0
# 1     2.0    4.0
# 2     3.0    1.0
# 3   120.0  236.0
# 4   120.0  354.0
# 5   140.0  192.0
# 6   140.0  294.0
# 7   120.0  263.0
# 8   172.0  199.0
# 9   150.0  168.0
# 10  140.0  239.0
# 11  130.0  275.0
# 12  130.0  266.0
# 13  110.0  211.0
# 14  150.0  283.0
# 15  120.0  219.0
# 16  120.0  340.0
# 17  150.0  226.0
# 18  150.0  247.0
# 19  140.0  239.0
# 20  135.0  234.0
# 21  130.0  233.0
# 22  140.0  226.0
# 23  150.0  243.0
# 24  140.0  199.0
# 25  160.0  302.0
# 26  150.0  212.0
# 27  110.0  175.0
# 28  140.0  417.0
# 29  130.0  197.0
# 30  105.0  198.0
# 31  120.0  177.0
# 32  130.0  219.0
# 33  125.0  273.0
# 34  125.0  213.0
# 35  142.0  177.0
# 36  135.0  304.0
# 37  150.0  232.0
# 38  155.0  269.0
# 39  160.0  360.0
# 40  140.0  308.0
# 41  130.0  245.0
# 42  104.0  208.0
# 43  130.0  264.0
# 44  140.0  321.0
# 45  120.0  325.0
# 46  140.0  235.0
# 47    NaN    NaN
# 48    NaN    NaN
# 49    NaN    NaN
# 50    NaN    NaN

# %%
plt.boxplot(df_without_higher_outlier)
df_without_higher_outlier.plot(kind='bar')

# %%
#dataframe without lower and higher outlier is as follows
df_without_significant_outlier = df[~((df < lower_outlier)|(df > higher_outlier))]

# %%
df_without_significant_outlier
# Out:
#        v1     v2
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3   120.0  236.0
# 4   120.0  354.0
# 5   140.0  192.0
# 6   140.0  294.0
# 7   120.0  263.0
# 8   172.0  199.0
# 9   150.0  168.0
# 10  140.0  239.0
# 11  130.0  275.0
# 12  130.0  266.0
# 13  110.0  211.0
# 14  150.0  283.0
# 15  120.0  219.0
# 16  120.0  340.0
# 17  150.0  226.0
# 18  150.0  247.0
# 19  140.0  239.0
# 20  135.0  234.0
# 21  130.0  233.0
# 22  140.0  226.0
# 23  150.0  243.0
# 24  140.0  199.0
# 25  160.0  302.0
# 26  150.0  212.0
# 27  110.0  175.0
# 28  140.0  417.0
# 29  130.0  197.0
# 30  105.0  198.0
# 31  120.0  177.0
# 32  130.0  219.0
# 33  125.0  273.0
# 34  125.0  213.0
# 35  142.0  177.0
# 36  135.0  304.0
# 37  150.0  232.0
# 38  155.0  269.0
# 39  160.0  360.0
# 40  140.0  308.0
# 41  130.0  245.0
# 42  104.0  208.0
# 43  130.0  264.0
# 44  140.0  321.0
# 45  120.0  325.0
# 46  140.0  235.0
# 47    NaN    NaN
# 48    NaN    NaN
# 49    NaN    NaN
# 50    NaN    NaN

# %%
plt.boxplot(df_without_significant_outlier)
df_without_significant_outlier.plot(kind='bar')

# %%
#let check all columns v1 and v2 outlier free or not 
df_without_significant_outlier1 = df[~((df < lower_outlier)|(df > higher_outlier))].all(axis=0)

# %%
#hence it answer is true i.e. outlier free 
df_without_significant_outlier1
# Out:
# v1    True
# v2    True
# dtype: bool

# %%
#now we can impute NaN values using one of imputer method like Imputer() or SimpleImputer() 
#or any Pandas method fillna()

# %%
#created by @ maee in mind..!
